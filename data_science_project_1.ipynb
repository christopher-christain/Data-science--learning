# %% [markdown]
# <a href="https://colab.research.google.com/github/christopher-christain/Data-science--learning/blob/main/data_science_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ("dataset_practice.txt", "r") as file1:
  filecontent = file1.read()
  print(filecontent)
# Out:
# ﻿The boy is a crazy goat
# I cant speek to him
# We have lot of work to do
# Cant switch nigga

# %%
file1.close()

# %%
with open ("dataset_practice.txt", "r") as file1:
  file_lines = file1.readlines()
  print(file_lines)
# Out:
# ['\ufeffThe boy is a crazy goat\n', 'I cant speek to him\n', 'We have lot of work to do\n', 'Cant switch nigga']

# %%
with open ("dataset_practice.txt", "r") as file1:
  for line in file1:
    print(line)
# Out:
# ﻿The boy is a crazy goat
#
# I cant speek to him
#
# We have lot of work to do
#
# Cant switch nigga

# %%
with open ("dataset_practice.txt", "r") as file1:
  while True:
    line = file1.readline()
    if not line:
      break
    print(line)
# Out:
# ﻿The boy is a crazy goat
#
# I cant speek to him
#
# We have lot of work to do
#
# Cant switch nigga

# %%
# Your local university's Raptors fan club maintains a register of its active
# members on a .txt document. Every month they update the file by removing the
# members who are not active. You have been tasked with automating this with
# your Python skills.
# Given the file currentMem, Remove each member with a 'no' in their Active column. Keep track of each of the removed members and append them to the exMem file. Make sure that the format of the original files in preserved. (Hint: Do this by reading/writing whole lines and ensuring the header remains )
# Run the code block below prior to starting the exercise. The skeleton code has been provided for you. Edit only the cleanFiles function.

# %%
#Run this prior to starting the exercise
from random import randint as rnd

memReg = '/members.txt'
exReg = '/inactive.txt'
fee =('yes','no')

def genFiles(current,old):
    with open(current,'w+') as writefile:
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"

        for rowno in range(20):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[rnd(0,1)]))


    with open(old,'w+') as writefile:
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"
        for rowno in range(3):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[1]))


genFiles(memReg,exReg)

# %%
import pandas as pd
songs  = {"Album": ["thriller", "bad-binny", "dark side of the moon", "back o gasses"], "released": [2000, 1998, 2001, 2001], "length": ["00:44:34", "00:32:25", "00:12:22", "00:2:11"]}
songs_new_frame = songs_frame
songs_new_frame.index = ["a", "b", "c", "d"]
songs_new_frame
# Out:
#                    Album  released    length
# a               thriller      2000  00:44:34
# b              bad-binny      1998  00:32:25
# c  dark side of the moon      2001  00:12:22
# d          back o gasses      2001   00:2:11

# %%
songs_frame.iloc [0, 0]
# Out:
# np.int64(2000)

# %%
songs_frame.iloc [1, 0]
# Out:
# 'bad-binny'

# %%
x = songs_frame [["released"]]
x
# Out:
#    released
# 0      2000
# 1      1998
# 2      2001
# 3      2001

# %%
x.iloc [0,0]
# Out:
# np.int64(2000)

# %%
songs_frame["released"] > 1998
# Out:
# a     True
# b    False
# c     True
# d     True
# Name: released, dtype: bool

# %%
df1 = songs_frame[songs_frame["released"]>1998]
df1
# Out:
#                    Album  released    length
# a               thriller      2000  00:44:34
# c  dark side of the moon      2001  00:12:22
# d          back o gasses      2001   00:2:11

# %%
import pandas as pd
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print (s[2])
# Out:
# 30

# %%
print(s.iloc[3])
# Out:
# 40

# %%
print(s[1:4])
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

x = {"name": ["john", "james", "kinsley", "bright", "christopher"], "ID": [1, 2, 3, 4, 5], "department": ["engineering","physics", "sociology", "chemistry", "medicine"], "salary": [2000, 4000, 50000, 60000, 700]}

df = pd.DataFrame(x)
df
# Out:
#           name  ID   department  salary
# 0         john   1  engineering    2000
# 1        james   2      physics    4000
# 2      kinsley   3    sociology   50000
# 3       bright   4    chemistry   60000
# 4  christopher   5     medicine     700

# %%
x = df[["department"]]
print (x)
# Out:
#     department
# 0  engineering
# 1      physics
# 2    sociology
# 3    chemistry
# 4     medicine

# %%
type (x)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df[["department", "ID", "name"]]
x
# Out:
#     department  ID         name
# 0  engineering   1         john
# 1      physics   2        james
# 2    sociology   3      kinsley
# 3    chemistry   4       bright
# 4     medicine   5  christopher

# %%
x.loc[0:2]
# Out:
#     department  ID     name
# 0  engineering   1     john
# 1      physics   2    james
# 2    sociology   3  kinsley

# %%
x.iloc[0:2]
# Out:
#     department  ID   name
# 0  engineering   1   john
# 1      physics   2  james

# %%
x.iloc[0:2, 0:3]
# Out:
#     department  ID   name
# 0  engineering   1   john
# 1      physics   2  james

# %%
dm = x.loc[0:3, "name": "ID"]
dm
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
# %pip install xlrd openpyxl
python !pip install requests

# %%
# Import required library

import pandas as pd

# %%
# Read data from CSV file

csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv'
df = pd.read_csv(csv_path)

# %%
df
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
# Read data from Excel File and print the first five rows

xlsx_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n9LOuKI9SlUa1b5zkaCMeg/Product-sales.xlsx'
df = pd.read_excel(xlsx_path)
df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
# 4        5     Monitor  Electronics         1    300    300 2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
x = df[["Quantity"]]
x
# Out:
#    Quantity
# 0         2
# 1         3
# 2         5
# 3        10
# 4         1

# %%
df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
# 4        5     Monitor  Electronics         1    300    300 2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
x = df[["Product", "Quantity"]]
x
# Out:
#       Product  Quantity
# 0      Laptop         2
# 1  Smartphone         3
# 2  Desk Chair         5
# 3    Notebook        10
# 4     Monitor         1

# %%
x = df[["Quantity"]]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y = df[["Quantity", "Product", "CustomerCity"]]
y
# Out:
#    Quantity     Product CustomerCity
# 0         2      Laptop     New York
# 1         3  Smartphone  Los Angeles
# 2         5  Desk Chair      Chicago
# 3        10    Notebook      Houston
# 4         1     Monitor        Miami

# %%
df.iloc[0:2]
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
#
#   CustomerCity
# 0     New York
# 1  Los Angeles

# %%
df.iloc[0:4]
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston

# %%
df.loc[0:2, "Quantity": "CustomerCity"]
# Out:
#    Quantity  Price  Total  OrderDate CustomerCity
# 0         2    800   1600 2022-01-10     New York
# 1         3    600   1800 2022-02-15  Los Angeles
# 2         5    150    750 2022-03-12      Chicago

# %%
df.iloc [0:2, 0:3]
# Out:
#    OrderID     Product     Category
# 0        1      Laptop  Electronics
# 1        2  Smartphone  Electronics

# %%
df.loc[0:2, "Product"]
# Out:
# 0        Laptop
# 1    Smartphone
# 2    Desk Chair
# Name: Product, dtype: object

# %%
import numpy as np

# %%
u = np.array([2,1])

v = np.array([4, 5])

z = u * v

z
# Out:
# array([8, 5])

# %%
u = np.array([1,2])

v = np.array([3,1])

result = np.dot(u,v)

result
# Out:
# np.int64(5)

# %%
u = np.array([2, 3, 4, 7, 8])

mean_a= u.mean()

mean_a

max_a = u.max()
max_a
# Out:
# np.int64(8)

# %%
np.pi

x = np.array ([0, np.pi/2, np.pi])

y = np.sin(x)

y
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np. linspace (0, 2*np.pi, 100)

y = np.sin(x)

# %matplotlib inline
plt.plot(x, y)

# %%
# Out:
# array([0.        , 6.28318531])

# %%
print(np.__version__)
# Out:
# 2.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt


arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 5, 10, 8, 2, 33])

# to perform various operation in numpy we use the following ways

arr3 = np.add(arr1, arr2) # this is tho add the arr1 and arr2 together
arr4 = np.subtract(arr1, arr2) # this is to subtract numbers in array
arr5 = np.multiply(arr1, arr2) # this is to multiple tthe array
arr6 = np.divide(arr1, arr2)

print (arr1, arr2, arr3, arr4, arr5, arr6)
# Out:
# [10 20 30 40 50 60] [ 3  5 10  8  2 33] [13 25 40 48 52 93] [ 7 15 20 32 48 27] [  30  100  300  320  100 1980] [ 3.33333333  4.          3.          5.         25.          1.81818182]

# %%
x = np.dot(arr1, arr2)
x
# Out:
# np.int64(2830)

# %%
import numpy as np

a = [[2, 8, 9], [8, 4, 6], [9, 5, 2] ]

A = np.array(a)

A
# Out:
# array([[2, 8, 9],
#        [8, 4, 6],
#        [9, 5, 2]])

# %%
A.ndim
# Out:
# 2

# %%
A.size
# Out:
# 9

# %%
A.shape
# Out:
# (3, 3)

# %%
A[1][2]
# Out:
# np.int64(6)

# %%
X=np.array([[1,0],[0,1]])

Y=np.array([[2,2],[2,2]])

Z=np.dot(X,Y)
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
# !pip install pycoingecko

# %%
from pycoingecko import CoinGeckoAPI

# %%
cg = CoinGeckoAPI()
bitcoin_data = cg.get_coin_market_chart_by_id(id = "bitcoin", vs_currency="usd", days=30)
bitcoin_data
# Out:
# {'prices': [[1747411789969, 104160.56764282625],
#   [1747415063203, 104068.97915372228],
#   [1747418678044, 103976.81475435526],
#   [1747422299413, 103804.54780310261],
#   [1747425898487, 103799.70381025353],
#   [1747429491917, 103617.4746044224],
#   [1747433098222, 103673.4945246536],
#   [1747436673139, 103467.28985993791],
#   [1747440580062, 103533.26669721663],
#   [1747443897036, 103374.05076215406],
#   [1747447494627, 102834.21312072649],
#   [1747451376276, 103261.20227671404],
#   [1747454681885, 103427.18317517905],
#   [1747458371449, 103624.29922408522],
#   [1747461889765, 103447.46486301252],
#   [1747465774446, 103477.33282267097],
#   [1747469361812, 103461.57411690436],
#   [1747472985561, 103486.17664215172],
#   [1747476585506, 102953.19338310153],
#   [1747480096204, 102888.81365330738],
#   [1747483483260, 103006.73892894214],
#   [1747487099926, 102970.03327807052],
#   [1747490734448, 102770.92765223501],
#   [1747494144629, 103084.1477956473],
# ...

# %%
bitcoin_data ["prices"]
# Out:
# [[1747411789969, 104160.56764282625],
#  [1747415063203, 104068.97915372228],
#  [1747418678044, 103976.81475435526],
#  [1747422299413, 103804.54780310261],
#  [1747425898487, 103799.70381025353],
#  [1747429491917, 103617.4746044224],
#  [1747433098222, 103673.4945246536],
#  [1747436673139, 103467.28985993791],
#  [1747440580062, 103533.26669721663],
#  [1747443897036, 103374.05076215406],
#  [1747447494627, 102834.21312072649],
#  [1747451376276, 103261.20227671404],
#  [1747454681885, 103427.18317517905],
#  [1747458371449, 103624.29922408522],
#  [1747461889765, 103447.46486301252],
#  [1747465774446, 103477.33282267097],
#  [1747469361812, 103461.57411690436],
#  [1747472985561, 103486.17664215172],
#  [1747476585506, 102953.19338310153],
#  [1747480096204, 102888.81365330738],
#  [1747483483260, 103006.73892894214],
#  [1747487099926, 102970.03327807052],
#  [1747490734448, 102770.92765223501],
#  [1747494144629, 103084.1477956473],
#  [1747497869896, 103048.13639309886],
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(bitcoin_data["prices"], columns = ["TimeStamp", "price"] )
df
# Out:
#          TimeStamp          price
# 0    1747411789969  104160.567643
# 1    1747415063203  104068.979154
# 2    1747418678044  103976.814754
# 3    1747422299413  103804.547803
# 4    1747425898487  103799.703810
# ..             ...            ...
# 717  1749992579852  105197.649415
# 718  1749996213342  105520.101712
# 719  1749999816426  105700.748946
# 720  1750003427267  105581.577636
# 721  1750005349000  105412.113138
#
# [722 rows x 2 columns]

# %%
date["Date"] = pd.to_datetime(bitcoin_data["TimeStamp"], unit = "ms" )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-189090115> in <cell line: 0>()
# ----> 1 date["Date"] = pd.to_datetime(bitcoin_data["TimeStamp"], unit = "ms" )
#
# KeyError: 'TimeStamp'

# %%
# !pip install nba_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.3/285.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from nba_api.stats.static import teams
import matplotlib.pyplot as plt

# %%
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
nba_teams = teams.get_teams()
nba_teams
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
dict_nba_team=one_dict(nba_teams)
df_teams=pd.DataFrame(dict_nba_team)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
import requests

filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl"

def download(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)

download(filename, "Golden_State.pkl")

# %%
file_name = "Golden_State.pkl"
games = pd.read_pickle(file_name)
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22019  1610612744               GSW  Golden State Warriors  1521900066
# 1     22019  1610612744               GSW  Golden State Warriors  1521900058
# 2     22019  1610612744               GSW  Golden State Warriors  1521900039
# 3     22019  1610612744               GSW  Golden State Warriors  1521900020
# 4     22019  1610612744               GSW  Golden State Warriors  1521900007
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2019-07-12  GSW vs. LAL  L  200   87  ...   0.800  13.0  29.0  42.0   13
# 1  2019-07-10    GSW @ DEN  W  201   73  ...   0.867   7.0  27.0  34.0   10
# 2  2019-07-08    GSW @ LAL  W  200   88  ...   0.621   8.0  29.0  37.0   21
# 3  2019-07-07  GSW vs. TOR  W  201   80  ...   0.923   6.0  37.0  43.0   18
# 4  2019-07-05  GSW vs. CHA  L  200   85  ...   0.889   8.0  28.0  36.0   19
#
#     STL  BLK   TOV  PF  PLUS_MINUS
# ...

# %%
games_home=games[games['MATCHUP']=='GSW vs. TOR']
games_away=games[games['MATCHUP']=='GSW @ TOR']

# %%
fig, ax = plt.subplots()

games_away.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
games_home.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
ax.legend(["away", "home"])
plt.show()

# %%
# !pip install requests

# %%
import requests

# %%
url = "https://www.ibm.com/"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
r.request.headers
# Out:
# {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=BE9587A420C73928F185CDD1C528DCF4~-1~...~-1~-1~-1; bm_sz=DA3C023020B2E656718D4AEF85C7FAA6~~4535348~3159366'}

# %%
r.request.body

# %%
r.text[0:100]
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n  '

# %%
# Import Beautiful Soup to parse the web page content
import requests
from bs4 import BeautifulSoup

# %%
# Specify the URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/IBM'
# Send an HTTP GET request to the webpage
response = requests.get(url)
# Store the HTML content in a variable
html_content = response.text
# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')
# Display a snippet of the HTML content
print(html_content[:500])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vect

# %%
# Find all <a> tags (anchor tags) in the HTML
links = soup.find_all('a')
# Iterate through the list of links and print their text
for  link in links:
    print(link.text)
# Out:
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Special pages
#
#
#
#
#
#
#
#
# Search
#
# Donate
# Create account
# Log in
# Donate
#  Create account
#  Log in
# learn more
# Contributions
# Talk
#
# (Top)
#
#
#
# 1
# History
#
#
#
#
# 1.1
# 1910s–1950s
#
#
#
#
# 1.2
# 1960s–1980s
#
#
#
#
# 1.3
# 1990s–2000s
#
#
#
#
# 1.4
# 2010s–present
#
#
#
#
# 2
# Corporate affairs
#
#
#
#
# 2.1
# Business trends
#
#
#
#
# 2.2
# Board and shareholders
#
#
#
#
# 2.3
# Headquarters and offices
#
#
#
#
# 3
# Products
#
#
#
#
# 3.1
# Hardware
#
#
#
#
# 3.1.1
# Mainframe computers
#
#
#
#
# 3.1.2
# Microprocessors
#
#
#
#
# 3.1.3
# Quantum computing
#
#
#
#
# 3.2
# Software
#
#
#
#
# 3.3
# Cloud services
#
#
#
#
# 3.4
# Artificial intelligence
#
#
#
#
# 3.5
# Consulting
#
#
#
#
# 4
# Research
#
#
#
#
# 4.1
# Patents
#
#
#
#
# 5
# Brand and reputation
#
#
#
#
# 5.1
# ...

# %%
# !pip install randomuser
# !pip install pandas
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=7dc99e7ada95c73b77867cf2b6e891f95b408302a66e3e0d4e598b882e893222
#   Stored in directory: /root/.cache/pip/wheels/fc/8d/74/bcdd5e8a9433bfa4c4f9c1cccbfec40139322a28d77f61e45e
# Successfully built randomuser
# ...

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
# we want to get 10 random users

some_list = r.generate_users(10)

# %%
some_list

# %%
name = r.get_full_name()
name
# Out:
# 'حامد گلشن'

# %%
for user in some_list:
  print(user.get_full_name(), " ", user.get_email())
# Out:
# Arijus Mogen   arijus.mogen@example.com
# Blake Lowe   blake.lowe@example.com
# Marlene Matthews   marlene.matthews@example.com
# Hedy Bogner   hedy.bogner@example.com
# Elif Akyüz   elif.akyuz@example.com
# Duygu Klerkx   duygu.klerkx@example.com
# Åsa Ås   asa.as@example.com
# Jaxon Patel   jaxon.patel@example.com
# Derrick Mason   derrick.mason@example.com
# Lorenzo Gutierrez   lorenzo.gutierrez@example.com

# %%
for user in some_list:
  print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/83.jpg
# https://randomuser.me/api/portraits/men/28.jpg
# https://randomuser.me/api/portraits/women/85.jpg
# https://randomuser.me/api/portraits/women/86.jpg
# https://randomuser.me/api/portraits/women/45.jpg
# https://randomuser.me/api/portraits/women/80.jpg
# https://randomuser.me/api/portraits/women/6.jpg
# https://randomuser.me/api/portraits/men/15.jpg
# https://randomuser.me/api/portraits/men/42.jpg
# https://randomuser.me/api/portraits/men/14.jpg
