# %%
# DATA CLEANING FOR AN AIRBNB USING PANDAS

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\User\Desktop\mypython\data-set-projects-yt\Airbnb_Open_Data.csv")

# %%
data.head()

# %%
# for checking all the columns
data.columns

# %%
data.info()

# %%
data["license"]

# %%
# DATA CLEANING PROCESSES, WE WILL FOLLOW
"""
DELETING REDUNDANT COLUMNS
RENAMING THE COLUMNS
DROPPING DUPLICATES
CLEANING INDIVIDUAL COLUMNS
REMOVE THE NAN VALUES FROM THE DATA SET
CHECK FOR SOME MORE TRANSFORMATION
"""

# %%
#PERFORMING THE FIRST TASK
# DELETING REDUNDANT COLUMNS

# %%
data.columns

# %%
# STEPS IN PERFORMING THIS TASK
"""
    WE WANT TO CREATE A LIST OF COLUMNS WE WANT TO SAVE AND LIST OF COLUMNS
    WE WANT TO DROP
"""

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license', 'id']

# %%
len(columns_to_keep)

# %%
len(columns_to_drop)

# %%
df = data[columns_to_keep]
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
# 2nd method, dropping columns

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
data.drop(columns = columns_to_drop, inplace = True)

# %%
data.shape
# Out:
# (102599, 19)

# %%
# DATA CLEANING PROCESSES, WE WILL FOLLOW
"""
DELETING REDUNDANT COLUMNS (done)
RENAMING THE COLUMNS
DROPPING DUPLICATES
CLEANING INDIVIDUAL COLUMNS
REMOVE THE NAN VALUES FROM THE DATA SET
CHECK FOR SOME MORE TRANSFORMATION
"""

# %%
# RENAMING THR COLUMNS
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# we want tot raname the name column to lowercase

data.rename(columns = {"NAME": "Name"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# we can decide o change all the columns to capital letter through iteration

# %%
new_columns_names = []
for i in data.columns:
    new_columns_names.append(i.upper())

# %%
type(new_columns_names)
# Out:
# list

# %%
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify.columns = new_columns_names

# %%
data = new_dataframe_to_modify

# %%
data.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %%
"""
DELETING REDUNDANT COLUMNS (done)
RENAMING THE COLUMNS (done)
DROPPING DUPLICATES (done)
CLEANING INDIVIDUAL COLUMNS
REMOVE THE NAN VALUES FROM THE DATA SET
CHECK FOR SOME MORE TRANSFORMATION
"""
# Out:
# '\nDELETING REDUNDANT COLUMNS (done)\nRENAMING THE COLUMNS (done)\nDROPPING DUPLICATES\nCLEANING INDIVIDUAL COLUMNS\nREMOVE THE NAN VALUES FROM THE DATA SET\nCHECK FOR SOME MORE TRANSFORMATION\n'

# %%
# DROPPING DUPLICATE
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 102594     True
# 102595     True
# 102596     True
# 102597     True
# 102598     True
# Length: 102599, dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
# This confirms that we have sucessfully dropped the duplicates in the data, since it gives us zero
data.duplicated().sum()
# Out:
# 0

# %%
"""
DELETING REDUNDANT COLUMNS (done)
RENAMING THE COLUMNS (done)
DROPPING DUPLICATES (done)
REMOVE THE NAN VALUES FROM THE DATA SET
CLEANING INDIVIDUAL COLUMNS
CHECK FOR SOME MORE TRANSFORMATION
"""
# Out:
# '\nDELETING REDUNDANT COLUMNS (done)\nRENAMING THE COLUMNS (done)\nDROPPING DUPLICATES (done)\nCLEANING INDIVIDUAL COLUMNS\nREMOVE THE NAN VALUES FROM THE DATA SET\nCHECK FOR SOME MORE TRANSFORMATION\n'

# %%
# REMOVING THE NAN VALUES
data.isna().sum() # this reveals the amount of nan per column in the data set
# Out:
# NAME                        250
# HOST ID                       0
# HOST_IDENTITY_VERIFIED      289
# HOST NAME                   404
# NEIGHBOURHOOD GROUP          29
# NEIGHBOURHOOD                16
# LAT                           8
# LONG                          8
# COUNTRY                     532
# COUNTRY CODE                131
# INSTANT_BOOKABLE            105
# CANCELLATION_POLICY          76
# ROOM TYPE                     0
# CONSTRUCTION YEAR           214
# PRICE                       247
# SERVICE FEE                 273
# MINIMUM NIGHTS              400
# NUMBER OF REVIEWS           183
# LAST REVIEW               15832
# dtype: int64

# %%
data.drop(columns = ["LAST REVIEW"], inplace = True)

# %%
data.isna().sum()
# Out:
# NAME                      250
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    289
# HOST NAME                 404
# NEIGHBOURHOOD GROUP        29
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   532
# COUNTRY CODE              131
# INSTANT_BOOKABLE          105
# CANCELLATION_POLICY        76
# ROOM TYPE                   0
# CONSTRUCTION YEAR         214
# PRICE                     247
# SERVICE FEE               273
# MINIMUM NIGHTS            400
# NUMBER OF REVIEWS         183
# dtype: int64

# %%
data.dropna(inplace= True) # this drops the nan values

# %%
data.isna().sum()
# Out:
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# dtype: int64

# %%
"""
DELETING REDUNDANT COLUMNS (done)
RENAMING THE COLUMNS (done)
DROPPING DUPLICATES (done)
REMOVE THE NAN VALUES FROM THE DATA SET (done)
CLEANING INDIVIDUAL COLUMNS 
CHECK FOR SOME MORE TRANSFORMATION
"""
# Out:
# '\nDELETING REDUNDANT COLUMNS (done)\nRENAMING THE COLUMNS (done)\nDROPPING DUPLICATES (done)\nREMOVE THE NAN VALUES FROM THE DATA SET (done)\nCLEANING INDIVIDUAL COLUMNS\nCHECK FOR SOME MORE TRANSFORMATION\n'

# %%
# cleaning individual columns
# we want to change the case of the host identity verified to upper case
# data["HOST_IDENTITY_VERIFIED"]
# data["HOST_IDENTITY_VERIFIED"].str.upper()
# to save the changes
data["HOST_IDENTITY_VERIFIED"]=data["HOST_IDENTITY_VERIFIED"].str.upper()

# %%
data["INSTANT_BOOKABLE"]
# Out:
# 0         False
# 1         False
# 4         False
# 5          True
# 7         False
#           ...
# 102029    False
# 102030     True
# 102031     True
# 102032    False
# 102040     True
# Name: INSTANT_BOOKABLE, Length: 99342, dtype: object

# %%
# change the true or false to 1's and 0's
data["INSTANT_BOOKABLE"].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: INSTANT_BOOKABLE, Length: 99342, dtype: int64

# %%
data["INSTANT_BOOKABLE"] = data["INSTANT_BOOKABLE"].apply(lambda x: 1 if x == True else 0)

# %%
data
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
type(data["INSTANT_BOOKABLE"][15])
# this will display error because we no longer have 15 after removing nan values
# Out:
# numpy.int64

# %%
#doing this eliminate that initial error
data.reset_index(inplace = True)

# %%
data
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
"""
DELETING REDUNDANT COLUMNS (done)
RENAMING THE COLUMNS (done)
DROPPING DUPLICATES (done)
REMOVE THE NAN VALUES FROM THE DATA SET (done)
CLEANING INDIVIDUAL COLUMNS  (done)
CHECK FOR SOME MORE TRANSFORMATION
"""
# Out:
# '\nDELETING REDUNDANT COLUMNS (done)\nRENAMING THE COLUMNS (done)\nDROPPING DUPLICATES (done)\nREMOVE THE NAN VALUES FROM THE DATA SET (done)\nCLEANING INDIVIDUAL COLUMNS  (done)\nCHECK FOR SOME MORE TRANSFORMATION\n'

# %%
data['PRICE'][15]
# Out:
# '$1,020 '

# %%
type(data['PRICE'][15])
# Out:
# str

# %%
data['PRICE'].str.lstrip('$')
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: PRICE, Length: 99342, dtype: object

# %%
# WE WANT TO STRIP THE DOLLAR SIGN FROM THE PRICE AND CONVERT IT TO INT, SINCE IT IS STRING BEFORE
data['PRICE'] = data['PRICE'].str.lstrip('$')

# %%
type(data['PRICE'][15])
# Out:
# str

# %%
data['PRICE'].str.replace(',', '').astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: int32

# %%
data['PRICE'] = data['PRICE'].str.replace(',', '').astype(int)

# %%
data['PRICE']
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: PRICE, Length: 99342, dtype: int32

# %%
type(data['PRICE'][15])
# Out:
# numpy.int32

# %%
data
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# we want to clean service fee, by converting the string to int and removing the dollar sign
data['SERVICE FEE']
# Out:
# 0        $193
# 1         $28
# 2         $41
# 3        $115
# 4        $212
#          ...
# 99337    $164
# 99338     $91
# 99339    $216
# 99340     $21
# 99341    $196
# Name: SERVICE FEE, Length: 99342, dtype: object

# %%
data['SERVICE FEE'].str.replace('$', '').astype(int)
# Out:
# 0        193
# 1         28
# 2         41
# 3        115
# 4        212
#         ...
# 99337    164
# 99338     91
# 99339    216
# 99340     21
# 99341    196
# Name: SERVICE FEE, Length: 99342, dtype: int32

# %%
data['SERVICE FEE'] = data['SERVICE FEE'].str.replace('$', '').astype(int)

# %%
data['SERVICE FEE']
# Out:
# 0        193
# 1         28
# 2         41
# 3        115
# 4        212
#         ...
# 99337    164
# 99338     91
# 99339    216
# 99340     21
# 99341    196
# Name: SERVICE FEE, Length: 99342, dtype: int32

# %%
data
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# to save the data to a new csv file

data.to_csv("cleansed_airbnb_data.csv")

# %%
#lets read the data
pd.read_csv("cleansed_airbnb_data.csv")
# Out:
#        Unnamed: 0   index                                              NAME  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 99337       99337  102029            Cozy room in a 2B with backyard access
# 99338       99338  102030                      An East Williamsburg Delight
# 99339       99339  102031                      Cozy bedroom in williamsburg
# 99340       99340  102032                            Spacious Room w/ 2 Bed
# 99341       99341  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
data.to_csv("cleansed_data_wo_index", index = False)

# %%
pd.read_csv("cleansed_data_wo_index")
# Out:
#         index                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data.drop(columns = ["index"], inplace = True )

# %%
data
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# TO SAVE THIS TO AN EXCEL SHEET
data.to_excel("excel_cleansed_data.xlsx")

# %%
data.to_excel("excel_cleaned_data_false.xlsx", index = False)

# %%
pd.read_excel("excel_cleaned_data_false.xlsx")
# Out:
#                                                    NAME      HOST ID  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...
